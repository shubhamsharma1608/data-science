# %%
import pandas as pd

# %%
data=pd.read_csv("Test.csv")

# %%
data
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %%
data.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4            Low          4.0  Cat_6

# %%
data.tail()
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7

# %%
data.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    2627.000000  2627.000000      2358.000000  2514.000000
# mean   463433.918919    43.649791         2.552587     2.825378
# std      2618.245698    16.967015         3.341094     1.551906
# min    458989.000000    18.000000         0.000000     1.000000
# 25%    461162.500000    30.000000         0.000000     2.000000
# 50%    463379.000000    41.000000         1.000000     2.000000
# 75%    465696.000000    53.000000         4.000000     4.000000
# max    467968.000000    89.000000        14.000000     9.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 10 columns):
# ID                 2627 non-null int64
# Gender             2627 non-null object
# Ever_Married       2577 non-null object
# Age                2627 non-null int64
# Graduated          2603 non-null object
# Profession         2589 non-null object
# Work_Experience    2358 non-null float64
# Spending_Score     2627 non-null object
# Family_Size        2514 non-null float64
# Var_1              2595 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 205.4+ KB

# %%
data.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married        50
# Age                  0
# Graduated           24
# Profession          38
# Work_Experience    269
# Spending_Score       0
# Family_Size        113
# Var_1               32
# dtype: int64

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# Create a bar plot of name vs grade
plt.bar(x=data.Age, height=data.Spending_Score)
plt.title('Customer segmentation')
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=90)


# Display the plot
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (10,4))
ax[0].bar(x=data.Age, height=data.Spending_Score, color='orange')
ax[0].set_title('Customer Segmentation')
ax[0].set_xticklabels(data.Family_Size, rotation=90)
fig.show()

# %%
var = data['Spending_Score']

# %%
plt.hist(var)
plt.show()

# %%
var1 = data["Age"]

# %%
plt.hist(var1)
plt.grid(color='#189AB4', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show()

# %%
plt.boxplot(var1)
plt.show()

# %%
df_sample = data[data['Age']>20]

# %%
df_sample
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 5     459003    Male          Yes   47       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 5                 0.0           High          5.0  Cat_4
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2484 rows x 10 columns]

# %%
df_sample.plot(x='Age', y=['Spending_Score','Family_Size'], kind='bar', figsize=(8,5))
plt.show()

# %%
data.Age.corr(data.Family_Size)
# Out:
# -0.2852367580851237

# %%
data.plot.scatter(title='AGE VS FAMILY SIZE', x='Age', y='Family_Size')
plt.show()

# %%
data1=df_sample.copy()

# %%
data1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 5     459003    Male          Yes   47       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 5                 0.0           High          5.0  Cat_4
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2484 rows x 10 columns]

# %%
data1.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married        48
# Age                  0
# Graduated           22
# Profession          38
# Work_Experience    254
# Spending_Score       0
# Family_Size        105
# Var_1               29
# dtype: int64

# %%
data1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 5     459003    Male          Yes   47       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 5                 0.0           High          5.0  Cat_4
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2484 rows x 10 columns]

# %%
data2=data1.drop(['Var_1','Profession','ID'],axis=1)

# %%
data2
# Out:
#       Gender Ever_Married  Age Graduated  Work_Experience Spending_Score  \
# 0     Female          Yes   36       Yes              0.0            Low
# 1       Male          Yes   37       Yes              8.0        Average
# 2     Female          Yes   69        No              0.0            Low
# 3       Male          Yes   59        No             11.0           High
# 5       Male          Yes   47       Yes              0.0           High
# ...      ...          ...  ...       ...              ...            ...
# 2622    Male           No   29        No              9.0            Low
# 2623  Female           No   35       Yes              1.0            Low
# 2624  Female           No   53       Yes              NaN            Low
# 2625    Male          Yes   47       Yes              1.0           High
# 2626  Female           No   43       Yes              9.0            Low
#
#       Family_Size
# 0             1.0
# 1             4.0
# 2             1.0
# 3             2.0
# 5             5.0
# ...           ...
# 2622          4.0
# 2623          1.0
# 2624          2.0
# 2625          5.0
# 2626          3.0
#
# [2484 rows x 7 columns]

# %%
data1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 5     459003    Male          Yes   47       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 5                 0.0           High          5.0  Cat_4
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2484 rows x 10 columns]

# %%
data2["Ever_Married"].fillna("NO", inplace = True)
data2["Graduated"].fillna("NO", inplace = True)
#data2["Profession"].fillna("Nil", inplace = True)
data2["Work_Experience"].fillna("0", inplace = True)
data2["Family_Size"].fillna("1", inplace = True)

# %%
data2.isnull().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# dtype: int64

# %%
data1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 5     459003    Male          Yes   47       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 5                 0.0           High          5.0  Cat_4
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2484 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder
cols = ["Gender","Ever_Married","Graduated","Spending_Score"]
#cols = ["Credit_History"]
le=LabelEncoder()
for col in cols:
    data2[col] = le.fit_transform(data2[col])

# %%
data2
# Out:
#       Gender  Ever_Married  Age  Graduated Work_Experience  Spending_Score  \
# 0          0             2   36          2               0               2
# 1          1             2   37          2               8               0
# 2          0             2   69          1               0               2
# 3          1             2   59          1              11               1
# 5          1             2   47          2               0               1
# ...      ...           ...  ...        ...             ...             ...
# 2622       1             1   29          1               9               2
# 2623       0             1   35          2               1               2
# 2624       0             1   53          2               0               2
# 2625       1             2   47          2               1               1
# 2626       0             1   43          2               9               2
#
#      Family_Size
# 0              1
# 1              4
# 2              1
# 3              2
# 5              5
# ...          ...
# 2622           4
# 2623           1
# 2624           2
# 2625           5
# 2626           3
#
# [2484 rows x 7 columns]

# %%
data2
# Out:
#       Gender  Ever_Married  Age  Graduated Work_Experience  Spending_Score  \
# 0          0             2   36          2               0               2
# 1          1             2   37          2               8               0
# 2          0             2   69          1               0               2
# 3          1             2   59          1              11               1
# 5          1             2   47          2               0               1
# ...      ...           ...  ...        ...             ...             ...
# 2622       1             1   29          1               9               2
# 2623       0             1   35          2               1               2
# 2624       0             1   53          2               0               2
# 2625       1             2   47          2               1               1
# 2626       0             1   43          2               9               2
#
#      Family_Size
# 0              1
# 1              4
# 2              1
# 3              2
# 5              5
# ...          ...
# 2622           4
# 2623           1
# 2624           2
# 2625           5
# 2626           3
#
# [2484 rows x 7 columns]

# %%
import seaborn as sns
sns.pairplot(data)
plt.show()

# %%
features = data2[data2.columns[0:7]]

# %%
features
# Out:
#       Gender  Ever_Married  Age  Graduated Work_Experience  Spending_Score  \
# 0          0             2   36          2               0               2
# 1          1             2   37          2               8               0
# 2          0             2   69          1               0               2
# 3          1             2   59          1              11               1
# 5          1             2   47          2               0               1
# ...      ...           ...  ...        ...             ...             ...
# 2622       1             1   29          1               9               2
# 2623       0             1   35          2               1               2
# 2624       0             1   53          2               0               2
# 2625       1             2   47          2               1               1
# 2626       0             1   43          2               9               2
#
#      Family_Size
# 0              1
# 1              4
# 2              1
# 3              2
# 5              5
# ...          ...
# 2622           4
# 2623           1
# 2624           2
# 2625           5
# 2626           3
#
# [2484 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# Normalize the numeric features so they're on the same scale
scaled_features = MinMaxScaler().fit_transform(features[data2.columns[0:7]])

# Get two principal components
pca = PCA(n_components=2).fit(scaled_features)
features_2d = pca.transform(scaled_features)
features_2d[0:7]
# Out:
# array([[ 5.69510469e-01,  1.41478244e-02],
#        [-6.62363463e-01,  4.08048550e-01],
#        [ 5.23012538e-01,  6.48953229e-02],
#        [-5.02461280e-01,  8.05128895e-04],
#        [-5.46090801e-01,  6.41077472e-02],
#        [-3.64433974e-01, -3.26304717e-01],
#        [ 2.11422656e-01,  8.64307210e-01]])

# %%
plt.scatter(features_2d[:,0],features_2d[:,1])
plt.xlabel('Dimension1')
plt.ylabel('Dimension 2')
plt.title('Data')
plt.show()

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    # Fit the data points
    kmeans.fit(features.values)
    # Get the WCSS (inertia) value
    wcss.append(kmeans.inertia_)
    
#Plot the WCSS values onto a line graph
plt.plot(range(1, 11), wcss)
plt.title('COUSTOMER SEGMENTAAION')
plt.xlabel('Number of clusters')
plt.show()

# %%
model = KMeans(n_clusters=3, init='k-means++', n_init=100, max_iter=1000)

# %%
km_clusters = model.fit_predict(features.values)

# %%
km_clusters
# Out:
# array([1, 1, 2, ..., 0, 0, 0], dtype=int32)

# %%
def plot_clusters(samples, clusters):
    col_dic = {0:'blue',1:'green',2:'orange'}
    mrk_dic = {0:'*',1:'x',2:'+'}
    colors = [col_dic[x] for x in clusters]
    markers = [mrk_dic[x] for x in clusters]
    for sample in range(len(clusters)):
        plt.scatter(samples[sample][0], samples[sample][1], color = colors[sample], marker=markers[sample], s=100)
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')
    plt.title('Customer Segmnetation')
    plt.show()

plot_clusters(features_2d, km_clusters)

# %%
from azureml.core import Workspace, Dataset

subscription_id = '3e12939b-5e19-47ce-a177-9b4bf39e7c8b'
resource_group = 'myrg1'
workspace_name = 'mywks123'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='dfghdfgh')
dataset.to_pandas_dataframe()
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male        False   22     False     Healthcare
# 1     462643  Female         True   38      True       Engineer
# 2     466315  Female         True   67      True       Engineer
# 3     461735    Male         True   67      True         Lawyer
# 4     462669  Female         True   40      True  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male        False   22     False           None
# 8064  464685    Male        False   35     False      Executive
# 8065  465406  Female        False   33      True     Healthcare
# 8066  467299  Female        False   27      True     Healthcare
# 8067  461879    Male         True   37      True      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# 1                 NaN        Average          3.0  Cat_4            A
# 2                 1.0            Low          1.0  Cat_6            B
# 3                 0.0           High          2.0  Cat_6            B
# 4                 NaN           High          6.0  Cat_6            A
# ...               ...            ...          ...    ...          ...
# 8063              0.0            Low          7.0  Cat_1            D
# 8064              3.0            Low          4.0  Cat_4            D
# 8065              1.0            Low          1.0  Cat_6            D
# 8066              1.0            Low          4.0  Cat_6            B
# 8067              0.0        Average          3.0  Cat_4            B
#
# [8068 rows x 11 columns]

# %%
data1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989       0          Yes   36       Yes       Engineer
# 1     458994       1          Yes   37       Yes     Healthcare
# 2     458996       0          Yes   69        No            NaN
# 3     459000       1          Yes   59        No      Executive
# 5     459003       1          Yes   47       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954       1           No   29        No     Healthcare
# 2623  467958       0           No   35       Yes         Doctor
# 2624  467960       0           No   53       Yes  Entertainment
# 2625  467961       1          Yes   47       Yes      Executive
# 2626  467968       0           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 5                 0.0           High          5.0  Cat_4
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2484 rows x 10 columns]

# %%
data
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %%
data2.isnull().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# dtype: int64

# %%
data2
# Out:
#       Gender  Ever_Married  Age  Graduated Work_Experience  Spending_Score  \
# 0          0             2   36          2               0               2
# 1          1             2   37          2               8               0
# 2          0             2   69          1               0               2
# 3          1             2   59          1              11               1
# 5          1             2   47          2               0               1
# ...      ...           ...  ...        ...             ...             ...
# 2622       1             1   29          1               9               2
# 2623       0             1   35          2               1               2
# 2624       0             1   53          2               0               2
# 2625       1             2   47          2               1               1
# 2626       0             1   43          2               9               2
#
#      Family_Size
# 0              1
# 1              4
# 2              1
# 3              2
# 5              5
# ...          ...
# 2622           4
# 2623           1
# 2624           2
# 2625           5
# 2626           3
#
# [2484 rows x 7 columns]

# %%
data2['Ever_Married'] = data2['Ever_Married'].astype('int64')

# %%
data2['Age'] = data2['Age'].astype('int64')

# %%
data2['Gender'] = data2['Gender'].astype('int64')

# %%
data2['Graduated'] = data2['Graduated'].astype('int64')

# %%
data2['Work_Experience'] = data2['Work_Experience'].astype('int64')

# %%
data2['Spending_Score'] = data2['Spending_Score'].astype('int64')

# %%
data2['Family_Size'] = data2['Family_Size'].astype('int64')

# %%
corr = data.corr()

# %%
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col1 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col3 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col2 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Work_Experience</th>        <th class="col_heading level0 col3" >Family_Size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7level0_row0" class="row_heading level0 row0" >ID</th>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col1" class="data row0 col1" >-0.0229397</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col2" class="data row0 col2" >-0.0254455</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row0_col3" class="data row0 col3" >0.0208301</td>
#             </tr>
#             <tr>
#                         <th id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7level0_row1" class="row_heading level0 row1" >Age</th>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col0" class="data row1 col0" >-0.0229397</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col2" class="data row1 col2" >-0.186238</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row1_col3" class="data row1 col3" >-0.285237</td>
#             </tr>
#             <tr>
#                         <th id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7level0_row2" class="row_heading level0 row2" >Work_Experience</th>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col0" class="data row2 col0" >-0.0254455</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col1" class="data row2 col1" >-0.186238</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row2_col3" class="data row2 col3" >-0.071253</td>
#             </tr>
#             <tr>
#                         <th id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7level0_row3" class="row_heading level0 row3" >Family_Size</th>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col0" class="data row3 col0" >0.0208301</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col1" class="data row3 col1" >-0.285237</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col2" class="data row3 col2" >-0.071253</td>
#                         <td id="T_eb5c9f30_582e_11ec_bd91_17afc56edbd7row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %%
sns.heatmap(corr, annot = True)
plt.show()

# %%
from sklearn.metrics import roc_auc_score

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model2 = KNeighborsClassifier(n_neighbors=4)

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_classes=2, n_features=20, random_state=27)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=27)

# %%
model2 = KNeighborsClassifier(n_neighbors=4)

# %%
model2
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %% [markdown]
# #![Screenshot 2021-12-08 at 7.57.29 PM.png](attachment:8fcb8b06-758b-4dd8-a7b8-b2c2df356e22.png)
